# %%
import pandas as pd

# %%
import pysubgroup as ps

# %%
df = pd.read_csv('overlap_50_manually_selected_features.csv')

# %%
df = df.loc[:, (df != df.iloc[0]).any()]

# %%
df
# Out:
#       vibration_level__median  vibration_level__mean  \
# 0                        19.0                   19.0
# 1                        21.0                   20.0
# 2                        20.0                   20.0
# 3                        21.0                   21.0
# 4                        22.0                   21.0
# ...                       ...                    ...
# 3640                     18.0                   19.0
# 3641                     18.0                   18.0
# 3642                     19.0                   19.0
# 3643                     18.0                   19.0
# 3644                     18.0                   18.0
#
#       vibration_level__median.1  vibration_level__standard_deviation  \
# 0                          19.0                                  2.0
# 1                          21.0                                  2.0
# 2                          20.0                                  2.0
# ...

# %%
data = df

target = ps.BinaryTarget ('fail_in_slice', 1.0)
searchspace = ps.create_selectors(data, ignore=['fail_in_slice'])
task = ps.SubgroupDiscoveryTask (
    data,
    target,
    searchspace,
    result_set_size=5,
    depth=3,
    qf=ps.SimpleBinomialQF())
results5d3 = ps.GpGrowth().execute(task)

# %%
pd.options.display.max_colwidth = 500
pd.set_option('display.max_rows', 500)
print(results5d3.to_dataframe())
# Out:
#     quality  \
# 0  0.077128
# 1  0.076401
# 2  0.076401
# 3  0.076401
# 4  0.076401
#
#                                                                                                      subgroup  \
# 0     max_no_maintenance_streak>=3.0 AND power_consumption__minimum==0.0 AND power_consumption__skewness==0.0
# 1             max_no_maintenance_streak>=3.0 AND power_consumption__skewness==0.0 AND pressure__skewness==0.0
# 2                 load__skewness==0.0 AND max_no_maintenance_streak>=3.0 AND power_consumption__skewness==0.0
# 3                     load__mean==1.0 AND max_no_maintenance_streak>=3.0 AND power_consumption__skewness==0.0
# 4  ambient_temperature__skewness==0.0 AND max_no_maintenance_streak>=3.0 AND power_consumption__skewness==0.0
#
#    size_sg  size_dataset  positives_sg  positives_dataset  size_complement  \
# 0       65          3645            42                250             3580
# 1       66          3645            42                250             3579
# ...

# %%
df.head()
# Out:
#    vibration_level__median  vibration_level__mean  vibration_level__median.1  \
# 0                     19.0                   19.0                       19.0
# 1                     21.0                   20.0                       21.0
# 2                     20.0                   20.0                       20.0
# 3                     21.0                   21.0                       21.0
# 4                     22.0                   21.0                       22.0
#
#    vibration_level__standard_deviation  \
# 0                                  2.0
# 1                                  2.0
# 2                                  2.0
# 3                                  2.0
# 4                                  2.0
#
#    vibration_level__longest_strike_below_mean  \
# 0                                         6.0
# 1                                         3.0
# 2                                         5.0
# 3                                         4.0
# ...

# %%
# Drop columns that end with '_skewness', '_kurtosis', '_variance', '_standard_deviation', or '_change'
df_remove_dist = df.drop(df.filter(regex='_skewness$|_kurtosis$|_variance$|_standard_deviation$|_change$').columns, axis=1)

# Display the updated DataFrame
print(df)
# Out:
#       vibration_level__median  vibration_level__mean  \
# 0                        19.0                   19.0
# 1                        21.0                   20.0
# 2                        20.0                   20.0
# 3                        21.0                   21.0
# 4                        22.0                   21.0
# ...                       ...                    ...
# 3640                     18.0                   19.0
# 3641                     18.0                   18.0
# 3642                     19.0                   19.0
# 3643                     18.0                   19.0
# 3644                     18.0                   18.0
#
#       vibration_level__median.1  vibration_level__longest_strike_below_mean  \
# 0                          19.0                                         6.0
# 1                          21.0                                         3.0
# 2                          20.0                                         5.0
# ...

# %%
data = df_remove_dist

target = ps.BinaryTarget ('fail_in_slice', 1.0)
searchspace = ps.create_selectors(data, ignore=['fail_in_slice'])
task = ps.SubgroupDiscoveryTask (
    data,
    target,
    searchspace,
    result_set_size=5,
    depth=2,
    qf=ps.SimpleBinomialQF())
results5d2 = ps.GpGrowth().execute(task)

# %%
print(results5d2.to_dataframe())
# Out:
#     quality  \
# 0  0.076401
# 1  0.075690
# 2  0.075690
# 3  0.075690
# 4  0.075690
#
#                                                              subgroup  \
# 0  max_no_maintenance_streak>=3.0 AND power_consumption__minimum==0.0
# 1                                      max_no_maintenance_streak>=3.0
# 2        max_no_maintenance_streak>=3.0 AND total_no_maintenance>=3.0
# 3                load__median==1.0 AND max_no_maintenance_streak>=3.0
# 4                  load__mean==1.0 AND max_no_maintenance_streak>=3.0
#
#    size_sg  size_dataset  positives_sg  positives_dataset  size_complement  \
# 0       66          3645            42                250             3579
# 1       67          3645            42                250             3578
# 2       67          3645            42                250             3578
# 3       67          3645            42                250             3578
# 4       67          3645            42                250             3578
#
# ...

# %%
data = df_remove_dist

target = ps.BinaryTarget ('fail_in_slice', 1.0)
searchspace = ps.create_selectors(data, ignore=['fail_in_slice'])
task = ps.SubgroupDiscoveryTask (
    data,
    target,
    searchspace,
    result_set_size=20,
    depth=4,
    qf=ps.SimpleBinomialQF())
results20d4 = ps.GpGrowth().execute(task)
# Out:
# C:\Users\20200604\AppData\Local\anaconda3\Lib\site-packages\pysubgroup\binary_target.py:356: RuntimeWarning: invalid value encountered in divide
#   p_subgroup = np.divide(positives_subgroup, instances_subgroup)

# %%
print(results20d4.to_dataframe())
# Out:
#      quality  \
# 0   0.076401
# 1   0.076401
# 2   0.076401
# 3   0.076401
# 4   0.076401
# 5   0.076401
# 6   0.076401
# 7   0.075690
# 8   0.075690
# 9   0.075690
# 10  0.075690
# 11  0.075690
# 12  0.075690
# 13  0.075690
# 14  0.075690
# 15  0.071715
# 16  0.071715
# 17  0.071715
# 18  0.071715
# 19  0.071360
#
#                                                                                                                                       subgroup  \
# 0                                                                           max_no_maintenance_streak>=3.0 AND power_consumption__minimum==0.0
# 1                                             max_no_maintenance_streak>=3.0 AND power_consumption__minimum==0.0 AND total_no_maintenance>=3.0
# 2                                                     load__median==1.0 AND max_no_maintenance_streak>=3.0 AND power_consumption__minimum==0.0
# ...

# %%
data = df_remove_dist

target = ps.BinaryTarget ('fail_in_slice', 1.0)
searchspace = ps.create_selectors(data, ignore=['fail_in_slice'])
task = ps.SubgroupDiscoveryTask (
    data,
    target,
    searchspace,
    result_set_size=6,
    depth=6,
    qf=ps.SimpleBinomialQF())
results6d6 = ps.GpGrowth().execute(task)
# Out:
# C:\Users\20200604\AppData\Local\anaconda3\Lib\site-packages\pysubgroup\binary_target.py:356: RuntimeWarning: invalid value encountered in divide
#   p_subgroup = np.divide(positives_subgroup, instances_subgroup)

# %%
print(results6d6.to_dataframe())
# Out:
#     quality  \
# 0  0.076401
# 1  0.076401
# 2  0.076401
# 3  0.076401
# 4  0.076401
# 5  0.076401
#
#                                                                                                                subgroup  \
# 0                                                    max_no_maintenance_streak>=3.0 AND power_consumption__minimum==0.0
# 1                      max_no_maintenance_streak>=3.0 AND power_consumption__minimum==0.0 AND total_no_maintenance>=3.0
# 2                              load__median==1.0 AND max_no_maintenance_streak>=3.0 AND power_consumption__minimum==0.0
# 3                                load__mean==1.0 AND max_no_maintenance_streak>=3.0 AND power_consumption__minimum==0.0
# 4  load__mean==1.0 AND max_no_maintenance_streak>=3.0 AND power_consumption__minimum==0.0 AND total_no_maintenance>=3.0
# 5          load__mean==1.0 AND load__median==1.0 AND max_no_maintenance_streak>=3.0 AND power_consumption__minimum==0.0
#
# ...

# %%
df0 = pd.read_csv('overlap_0_manually_selected_features.csv')
df0 = df0.loc[:, (df0 != df0.iloc[0]).any()]

# %%
# Drop columns that end with '_skewness', '_kurtosis', '_variance', '_standard_deviation', or '_change'
df0_remove_dist = df0.drop(df0.filter(regex='_skewness$|_kurtosis$|_variance$|_standard_deviation$|_change$').columns, axis=1)

# %%
data = df0_remove_dist

target = ps.BinaryTarget ('fail_in_slice', 1.0)
searchspace = ps.create_selectors(data, ignore=['fail_in_slice'])
task = ps.SubgroupDiscoveryTask (
    data,
    target,
    searchspace,
    result_set_size=6,
    depth=2,
    qf=ps.SimpleBinomialQF())
result_split0_size6_d2 = ps.GpGrowth().execute(task)

# %%
print(result_split0_size6_d2.to_dataframe())
# Out:
#     quality  \
# 0  0.084438
# 1  0.084438
# 2  0.072749
# 3  0.070580
# 4  0.070437
# 5  0.069782
#
#                                                                                        subgroup  \
# 0                                                                  max_no_maintenance_streak>=3
# 1                                      max_no_maintenance_streak>=3 AND total_no_maintenance>=3
# 2               max_no_maintenance_streak>=3 AND pressure__longest_strike_above_mean: [3.0:4.0[
# 3  max_no_maintenance_streak>=3 AND operating_temperature__longest_strike_below_mean: [3.0:4.0[
# 4                   load__longest_strike_above_mean: [3.0:4.0[ AND max_no_maintenance_streak>=3
# 5                                                machine_id==3 AND max_no_maintenance_streak>=3
#
#    size_sg  size_dataset  positives_sg  positives_dataset  size_complement  \
# 0       42          2430            30                175             2388
# ...

# %%
data = df0_remove_dist

target = ps.BinaryTarget ('fail_in_slice', 1.0)
searchspace = ps.create_selectors(data, ignore=['fail_in_slice'])
task = ps.SubgroupDiscoveryTask (
    data,
    target,
    searchspace,
    result_set_size=6,
    depth=4,
    qf=ps.SimpleBinomialQF())
result_split0_size6_d4 = ps.GpGrowth().execute(task)
print(result_split0_size6_d4.to_dataframe())
# Out:
# C:\Users\20200604\AppData\Local\anaconda3\Lib\site-packages\pysubgroup\binary_target.py:356: RuntimeWarning: invalid value encountered in divide
#   p_subgroup = np.divide(positives_subgroup, instances_subgroup)
#     quality  \
# 0  0.084438
# 1  0.084438
# 2  0.072749
# 3  0.072749
# 4  0.070580
# 5  0.070580
#
#                                                                                                                    subgroup  \
# 0                                                                                              max_no_maintenance_streak>=3
# 1                                                                  max_no_maintenance_streak>=3 AND total_no_maintenance>=3
# 2                                           max_no_maintenance_streak>=3 AND pressure__longest_strike_above_mean: [3.0:4.0[
# 3               max_no_maintenance_streak>=3 AND pressure__longest_strike_above_mean: [3.0:4.0[ AND total_no_maintenance>=3
# ...

# %%
(result_split0_size6_d4.to_dataframe()).to_csv('result_split0_size6_d4.csv', index=False)

# %%
(results6d6.to_dataframe()).to_csv('result_split50_size6_d6.csv', index=False)

# %%
df75 = pd.read_csv('overlap_75_manually_selected_features.csv')
df75 = df75.loc[:, (df75 != df75.iloc[0]).any()]
# Drop columns that end with '_skewness', '_kurtosis', '_variance', '_standard_deviation', or '_change'
df75_remove_dist = df75.drop(df75.filter(regex='_skewness$|_kurtosis$|_variance$|_standard_deviation$|_change$').columns, axis=1)

# %%
data = df75_remove_dist

target = ps.BinaryTarget ('fail_in_slice', 1.0)
searchspace = ps.create_selectors(data, ignore=['fail_in_slice'])
task = ps.SubgroupDiscoveryTask (
    data,
    target,
    searchspace,
    result_set_size=6,
    depth=4,
    qf=ps.SimpleBinomialQF())
result_split75_size6_d4 = ps.GpGrowth().execute(task)

print(result_split75_size6_d4.to_dataframe())
# Out:
# C:\Users\20200604\AppData\Local\anaconda3\Lib\site-packages\pysubgroup\binary_target.py:356: RuntimeWarning: invalid value encountered in divide
#   p_subgroup = np.divide(positives_subgroup, instances_subgroup)
#     quality                                           subgroup  size_sg  \
# 0  0.083156                       max_no_maintenance_streak>=3      133
# 1  0.083156  max_no_maintenance_streak>=3 AND total_no_main...      133
# 2  0.066759     machine_id==3 AND max_no_maintenance_streak>=3       84
# 3  0.066759  machine_id==3 AND max_no_maintenance_streak>=3...       84
# 4  0.066759  machine_age==36 AND max_no_maintenance_streak>...       84
# 5  0.066759  machine_age==36 AND machine_id==3 AND max_no_m...       84
#
#    size_dataset  positives_sg  positives_dataset  size_complement  \
# 0          7285            91                501             7152
# 1          7285            91                501             7152
# ...

# %%
(result_split75_size6_d4.to_dataframe()).to_csv('result_split75_size6_d4.csv', index=False)
